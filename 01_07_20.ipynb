# %% [markdown]
# <a href="https://colab.research.google.com/github/PrasadReddyGaddam/PYTHON/blob/master/01_07_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem Statement**
#
# The problem that we are going to solve here is that given a set of features that describe a tumour whether it is Malignant or Benign, our machine learning model must predict whether the tumour is Malignant or Benign. To train our machine learning model with tumour data, we will be using [SCLCData](https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/wbcd.csv)
#
# - 01-07-20 at [23]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# read the data
data = pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/wbcd.csv")
data
# Out:
#             id diagnosis  ...  symmetry_worst  dimension_worst
# 0     87139402         B  ...          0.2827          0.06771
# 1      8910251         B  ...          0.2940          0.07587
# 2       905520         B  ...          0.2998          0.07881
# 3       868871         B  ...          0.2102          0.06784
# 4      9012568         B  ...          0.2487          0.06766
# ..         ...       ...  ...             ...              ...
# 564  911320502         B  ...          0.2235          0.06925
# 565     898677         B  ...          0.2434          0.08488
# 566     873885         M  ...          0.3175          0.09772
# 567     911201         B  ...          0.2606          0.07810
# 568    9012795         M  ...          0.2730          0.08666
#
# [569 rows x 32 columns]

# %%
data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data.isnull().sum()
# Out:
# id                   0
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %%
# Preaparing i/o and droping id and diagnosis columns for input
X = data.drop(["id","diagnosis"],axis=1) 
X.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  dimension_worst
# 0        12.32         12.39  ...          0.2827          0.06771
# 1        10.60         18.95  ...          0.2940          0.07587
# 2        11.04         16.83  ...          0.2998          0.07881
# 3        11.28         13.39  ...          0.2102          0.06784
# 4        15.19         13.21  ...          0.2487          0.06766
#
# [5 rows x 30 columns]

# %%
#Accessing output
y = data.diagnosis
y.head()
# Out:
# 0    B
# 1    B
# 2    B
# 3    B
# 4    B
# Name: diagnosis, dtype: object

# %%
#Preaparing training and testing data 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=4)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (398, 30)
# (171, 30)
# (398,)
# (171,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#scalaling training data
scaled_X_train=pd.DataFrame(scaler.fit_transform(X_train),columns=X_train.columns)
scaled_X_train
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  dimension_worst
# 0       0.932609      1.148851  ...        0.621332         2.886912
# 1       0.071943      0.708110  ...       -0.325308         0.009750
# 2      -0.286424     -0.016763  ...       -0.723975        -1.167608
# 3      -0.318735     -0.719263  ...        0.596704        -0.285446
# 4       1.393785      0.457537  ...        1.184699         0.877066
# ..           ...           ...  ...             ...              ...
# 393    -0.145427     -1.889351  ...       -0.306837        -0.652586
# 394     1.896085      0.464249  ...       -1.033364        -0.689128
# 395    -0.668289      0.177879  ...        0.398140        -0.198087
# 396    -0.174801      0.054830  ...       -0.039007        -0.549809
# 397    -0.712350      1.142139  ...        0.515124        -0.907242
#
# [398 rows x 30 columns]

# %%
#scalaling testing data
scaled_X_test=pd.DataFrame(scaler.transform(X_test),columns=X_test.columns)
scaled_X_test
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  dimension_worst
# 0       0.621242     -1.012344  ...       -0.202168        -0.754791
# 1       0.133629      0.464249  ...        0.170331        -0.849573
# 2       1.517157     -0.770720  ...       -0.717818        -1.189306
# 3       0.421496      0.021271  ...       -0.111352        -0.179815
# 4      -1.105966     -1.602982  ...        0.042573        -0.349396
# ..           ...           ...  ...             ...              ...
# 166     0.201189      0.493333  ...        1.213944         1.488014
# 167    -0.768162     -1.916198  ...        0.164174         0.107958
# 168    -0.850410     -0.618586  ...       -0.810173        -0.714251
# 169    -1.254306      1.972164  ...       -0.905607        -0.641166
# 170     1.511282      1.211494  ...        0.410454         1.082619
#
# [171 rows x 30 columns]

# %%
# model building
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=6,metric="euclidean")

#applying knn object on dataset
#syntax: obj.fit(i,o)
knn.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')

# %%
#Predictins on data
y_train_pred = knn.predict(scaled_X_train)
y_train_pred
# Out:
# array(['M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B'], dtype=object)

# %%
# check accuracy classification report
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      1.00      0.98       256
#            M       1.00      0.92      0.96       142
#
#     accuracy                           0.97       398
#    macro avg       0.98      0.96      0.97       398
# weighted avg       0.97      0.97      0.97       398

# %%
# checking for optimum k value
# build the modes with multiple k vales
from sklearn.metrics import accuracy_score
scores = []
for k in range(1, 20):
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(scaled_X_train, y_train)
    pred_test = knn_model.predict(scaled_X_test)
    scores.append(accuracy_score(y_test, pred_test))
scores
# Out:
# [0.935672514619883,
#  0.935672514619883,
#  0.9532163742690059,
#  0.9532163742690059,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.9532163742690059,
#  0.9415204678362573,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.9415204678362573,
#  0.9532163742690059,
#  0.9590643274853801,
#  0.9473684210526315,
#  0.9473684210526315,
#  0.9415204678362573,
#  0.9415204678362573]

# %%
# visualizing scores and k values
plt.plot(range(1,20),scores,marker="o",markerfacecolor="r",color="b",linestyle="dotted")

# %%
#optimum value of k  = 7
final_model  = KNeighborsClassifier(n_neighbors=7,metric="euclidean")
final_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
#prediction on traing data
final_train_pred = final_model.predict(scaled_X_train)
final_train_pred
# Out:
# array(['M', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_train,final_train_pred),annot=True,fmt="3.0f") #fmt="d"

# %%
# Classificataion report
print(classification_report(y_train,final_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.97      1.00      0.98       256
#            M       0.99      0.94      0.97       142
#
#     accuracy                           0.98       398
#    macro avg       0.98      0.97      0.98       398
# weighted avg       0.98      0.98      0.98       398

# %%
# Prediction on test data
final_test_pred = final_model.predict(scaled_X_test)
final_test_pred
# Out:
# array(['B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M',
#        'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'M'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test,final_test_pred),annot=True,fmt="3.0f") #fmt="d"

# %%
print(classification_report(y_test,final_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.98      0.96       101
#            M       0.97      0.90      0.93        70
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171

# %%
y_test_prod = final_model.predict_proba(scaled_X_test)
y_test_prod = pd.DataFrame(y_test_prod)
y_test_prod
# Out:
#             0         1
# 0    1.000000  0.000000
# 1    0.285714  0.714286
# 2    0.000000  1.000000
# 3    0.000000  1.000000
# 4    1.000000  0.000000
# ..        ...       ...
# 166  0.000000  1.000000
# 167  1.000000  0.000000
# 168  1.000000  0.000000
# 169  1.000000  0.000000
# 170  0.142857  0.857143
#
# [171 rows x 2 columns]

# %%
#Roc curve
#TPR , FPR , THRESHOLD
from sklearn.metrics import roc_auc_score,roc_curve
m_prob = final_model.predict_proba(scaled_X_test)[:,1]
tpr , fpr, threshold =roc_curve(y_test,m_prob,pos_label="M")

# %%
plt.plot(fpr,tpr)

# %%
roc_auc_score(y_test,m_prob)
# Out:
# 0.9921499292786422

# %%
from sklearn.model_selection import KFold
kfold =KFold(n_splits=5)
kfold.get_n_splits(X,y)
# Out:
# 5

# %%
model_knn = KNeighborsClassifier(n_neighbors=7,metric="euclidean")
# model will be built for 5 times -> for loop
# some set of indices will be in test data()
# remaining  set of indices will be in traing data
# In each and every fold,it is splitting training and test data
# kfold will return the indices of records which are splitted
# to access records in that indices we are using iloc
score = []
for train_index,test_index in kfold.split(X,y):
  X_train,X_test = X.iloc[train_index],X.iloc[test_index]
  y_train,y_test = y.iloc[train_index],y.iloc[test_index]
  # pass X_train,y_train into knn algorithm
  model_knn.fit(X_train,y_train)
  # predict
  y_pred_test = model_knn.predict(X_test)
  #accuracy score of predict values(y_pred_test) and A.V (y_test)
  accuracy = accuracy_score(y_test,y_pred_test)
  score.append(accuracy)
print(score)
np.mean(score)
# Out:
# [0.9122807017543859, 0.9035087719298246, 0.956140350877193, 0.9473684210526315, 0.9469026548672567]
# 0.9332401800962584

# %%
plt.plot(score,marker="o",linestyle="--",markerfacecolor="red")
plt.grid()
plt.show()
