# %% [markdown]
# <a href="https://colab.research.google.com/github/PrasadReddyGaddam/PYTHON/blob/master/Assignment_21(20_06_20).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CSE-221710301019-PRASAD REDDY**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# - Read the dataset from the below path:

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv")
df.head()
# Out:
#   name_of_city  state_code  ... male_graduates  female_graduates
# 0      Abohar            3  ...           8612              7675
# 1    Achalpur           27  ...           5269              3594
# 2    Adilabad           28  ...           6797              3768
# 3   Adityapur           20  ...          12189              7036
# 4       Adoni           28  ...           7871              4031
#
# [5 rows x 22 columns]

# %% [markdown]
# 1. Check the data types and summary statistics of the dataset

# %%
df.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
df.shape
# Out:
# (493, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name_of_city                    493 non-null    object
#  1   state_code                      493 non-null    int64
#  2   state_name                      493 non-null    object
#  3   dist_code                       493 non-null    int64
#  4   population_total                493 non-null    int64
#  5   population_male                 493 non-null    int64
#  6   population_female               493 non-null    int64
#  7   0-6_population_total            493 non-null    int64
#  8   0-6_population_male             493 non-null    int64
#  9   0-6_population_female           493 non-null    int64
#  10  literates_total                 493 non-null    int64
#  11  literates_male                  493 non-null    int64
# ...

# %%
df.describe()
# Out:
#        state_code   dist_code  ...  male_graduates  female_graduates
# count  493.000000  493.000000  ...    4.930000e+02      4.930000e+02
# mean    18.643002   16.782961  ...    3.771556e+04      2.848680e+04
# std      9.297168   15.566131  ...    9.849574e+04      7.951556e+04
# min      1.000000    1.000000  ...    1.703000e+03      8.290000e+02
# 25%      9.000000    7.000000  ...    9.289000e+03      6.114000e+03
# 50%     19.000000   13.000000  ...    1.404900e+04      9.558000e+03
# 75%     27.000000   21.000000  ...    2.787200e+04      2.086600e+04
# max     35.000000   99.000000  ...    1.210040e+06      1.011097e+06
#
# [8 rows x 19 columns]

# %% [markdown]
# 3. Select random columns as Series and random columns as dataframe

# %%
#Random columns as series
r_series = df.sample(axis=1).iloc[:,0]
#sample function is similar to random which selects random samples and return a series if iloc[x:y,0]
#Here we cannot use n parameter since series is bydefault n=1
print(type(r_series))
print(r_series)
# Out:
# <class 'pandas.core.series.Series'>
# 0       3
# 1      27
# 2      28
# 3      20
# 4      28
#        ..
# 488    28
# 489    28
# 490    27
# 491     6
# 492    27
# Name: state_code, Length: 493, dtype: int64

# %%
#Random column as dataframe
r_df = df.sample(axis=1,n=2)
#sample function is similar to random which selects random samples and return a df ,n is no of random columns
print(type(r_df))
print(r_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                   location      state_name
# 0    30.1452928,74.1993043          PUNJAB
# 1     21.257584,77.5086754     MAHARASHTRA
# 2     19.0809075,79.560344  ANDHRA PRADESH
# 3    22.7834741,86.1576889       JHARKHAND
# 4    15.6322227,77.2728368  ANDHRA PRADESH
# ..                     ...             ...
# 488  18.1066576,83.3955506  ANDHRA PRADESH
# 489  17.9689008,79.5940544  ANDHRA PRADESH
# 490   20.745319,78.6021946     MAHARASHTRA
# 491  30.1290485,77.2673901         HARYANA
# 492  20.3887937,78.1204073     MAHARASHTRA
#
# [493 rows x 2 columns]

# %% [markdown]
# 3. Convert the data type of integer cols to float and float cols to integer

# %%
tofloat=df.select_dtypes(include='int64').astype(float)
toint=df.select_dtypes(include='float64').astype(int)
print('Converting int to float:\n')
print(tofloat.head(),'\n\n')
print('converting float to int:\n')
print(toint.head())
# Out:
# Converting int to float:
#
#    state_code  dist_code  ...  male_graduates  female_graduates
# 0         3.0        9.0  ...          8612.0            7675.0
# 1        27.0        7.0  ...          5269.0            3594.0
# 2        28.0        1.0  ...          6797.0            3768.0
# 3        20.0       24.0  ...         12189.0            7036.0
# 4        28.0       21.0  ...          7871.0            4031.0
#
# [5 rows x 16 columns]
#
#
# converting float to int:
#
#    effective_literacy_rate_total  ...  effective_literacy_rate_female
# 0                             79  ...                              73
# 1                             91  ...                              89
# 2                             80  ...                              72
# 3                             83  ...                              76
# 4                             68  ...                              60
#
# [5 rows x 3 columns]

# %% [markdown]
# 4. Visualize the missing values through heatmap

# %%
sns.heatmap(df.isna())
plt.show()

# %% [markdown]
# 5. Dropt the duplicate values if found any

# %%
df.duplicated().sum()
#No duplicates are found
# Out:
# 0

# %% [markdown]
# 6. Get the row which has highest population

# %%
df.sort_values(by="population_total",ascending=False).head(1)
#df.sort_values(by=("population_total"),ascending=False).iloc[:1,:]
# Out:
#         name_of_city  state_code  ... male_graduates  female_graduates
# 185  Greater Mumbai           27  ...         964964            837407
#
# [1 rows x 22 columns]

# %% [markdown]
# 7. Calculate the mean of the population total grouped by States and sort the population total in ascending order and plot a horizontal bar chart for that

# %%
df1=pd.DataFrame(df.groupby(df.state_name).population_total.mean()).sort_values(by='population_total')
df1
# Out:
#                            population_total
# state_name
# ANDAMAN & NICOBAR ISLANDS     100608.000000
# NAGALAND                      123777.000000
# MEGHALAYA                     143007.000000
# HIMACHAL PRADESH              169758.000000
# UTTARAKHAND                   223399.500000
# BIHAR                         258250.615385
# MANIPUR                       264986.000000
# PUDUCHERRY                    270900.500000
# MIZORAM                       291822.000000
# WEST BENGAL                   296123.098361
# HARYANA                       297611.150000
# ORISSA                        300323.400000
# MADHYA PRADESH                344471.593750
# ASSAM                         347788.500000
# CHHATTISGARH                  348657.555556
# RAJASTHAN                     360104.000000
# PUNJAB                        363867.250000
# KERALA                        393710.428571
# TRIPURA                       399688.000000
# UTTAR PRADESH                 401633.730159
# ...

# %%
df1.plot.barh(figsize=(5,10))
plt.show()

# %% [markdown]
# 8. Create a dataframe of five cities which have lowest population

# %%
df_low = df.sort_values(by="population_total").head(5)
df_low
# Out:
#     name_of_city  state_code  ... male_graduates  female_graduates
# 332       Nagda           23  ...           5707              4137
# 53     Banswara            8  ...           7837              6015
# 211  Hinganghat           27  ...           6684              4572
# 136       Datia           23  ...           7960              4757
# 376  Port Blair           35  ...           6717              5703
#
# [5 rows x 22 columns]

# %% [markdown]
# 9. Create a dataframe of  five cities which have highest  population

# %%
df_high = df.sort_values(by="population_total").tail(5)
df_high
# Out:
#            name_of_city  state_code  ... male_graduates  female_graduates
# 7            Ahmadabad           24  ...         435267            334591
# 184  Greater Hyderabad           28  ...         685402            478747
# 72            Bengaluru          29  ...         908363            682800
# 141              Delhi            7  ...        1210040           1011097
# 185     Greater Mumbai           27  ...         964964            837407
#
# [5 rows x 22 columns]

# %% [markdown]
# 10. Concatenate the top five and bottom five cities based on the population

# %%
pd.concat([df_high,df_low])
# Out:
#            name_of_city  state_code  ... male_graduates  female_graduates
# 7            Ahmadabad           24  ...         435267            334591
# 184  Greater Hyderabad           28  ...         685402            478747
# 72            Bengaluru          29  ...         908363            682800
# 141              Delhi            7  ...        1210040           1011097
# 185     Greater Mumbai           27  ...         964964            837407
# 332              Nagda           23  ...           5707              4137
# 53            Banswara            8  ...           7837              6015
# 211         Hinganghat           27  ...           6684              4572
# 136              Datia           23  ...           7960              4757
# 376         Port Blair           35  ...           6717              5703
#
# [10 rows x 22 columns]
